# %% [markdown]
# # Importing Libraries

# %%
import os
import cv2
import math
import glob
import matplotlib
import numpy as np
# %matplotlib inline
from numpy import *
from PIL import Image
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Process Correction Tape Images

# %%
# empty list
image_list = []
resized_images = []

# append image to list
for filename in glob.glob('D:/Datasets/Processed Images/SVM-Datasets/RAW STATIONERY/CORRECTION TAPE/*.jpg'):
    img = Image.open(filename)
    image_list.append(img)

# append resized images to list
for image in image_list:
    image = image.resize((84,84))
    resized_images.append(image)

# save resized images to new folder
# could also probably use os to create new folder
for (i, new) in enumerate(resized_images):
    new.save('{}{}{}'.format('D:/Datasets/Processed Images/SVM-Datasets/STATIONERY/1_',i+1,'.jpg'))

# %% [markdown]
# # Process Eraser Images

# %%
# empty list
image_list = []
resized_images = []

# append image to list
for filename in glob.glob('D:/Datasets/Processed Images/SVM-Datasets/RAW STATIONERY/ERASER/*.jpg'):
    img = Image.open(filename)
    image_list.append(img)

# append resized images to list
for image in image_list:
    image = image.resize((84,84))
    resized_images.append(image)

# save resized images to new folder
# could also probably use os to create new folder
for (i, new) in enumerate(resized_images):
    new.save('{}{}{}'.format('D:/Datasets/Processed Images/SVM-Datasets/STATIONERY/2_',i+1,'.jpg'))

# %% [markdown]
# # Process File Images

# %%
# empty list
image_list = []
resized_images = []

# append image to list
for filename in glob.glob('D:/Datasets/Processed Images/SVM-Datasets/RAW STATIONERY/FILE/*.jpg'):
    img = Image.open(filename)
    image_list.append(img)

# append resized images to list
for image in image_list:
    image = image.resize((84,84))
    resized_images.append(image)

# save resized images to new folder
# could also probably use os to create new folder
for (i, new) in enumerate(resized_images):
    new.save('{}{}{}'.format('D:/Datasets/Processed Images/SVM-Datasets/STATIONERY/3_',i+1,'.jpg'))

# %% [markdown]
# # Process Glue Images

# %%
# empty list
image_list = []
resized_images = []

# append image to list
for filename in glob.glob('D:/Datasets/Processed Images/SVM-Datasets/RAW STATIONERY/GLUE/*.jpg'):
    img = Image.open(filename)
    image_list.append(img)

# append resized images to list
for image in image_list:
    image = image.resize((84,84))
    resized_images.append(image)

# save resized images to new folder
# could also probably use os to create new folder
for (i, new) in enumerate(resized_images):
    new.save('{}{}{}'.format('D:/Datasets/Processed Images/SVM-Datasets/STATIONERY/4_',i+1,'.jpg'))

# %% [markdown]
# # Process Pen Images

# %%
# empty list
image_list = []
resized_images = []

# append image to list
for filename in glob.glob('D:/Datasets/Processed Images/SVM-Datasets/RAW STATIONERY/PEN/*.jpg'):
    img = Image.open(filename)
    image_list.append(img)

# append resized images to list
for image in image_list:
    image = image.resize((84,84))
    resized_images.append(image)

# save resized images to new folder
# could also probably use os to create new folder
for (i, new) in enumerate(resized_images):
    new.save('{}{}{}'.format('D:/Datasets/Processed Images/SVM-Datasets/STATIONERY/5_',i+1,'.jpg'))

# %% [markdown]
# # Process Pencil Images

# %%
# empty list
image_list = []
resized_images = []

# append image to list
for filename in glob.glob('D:/Datasets/Processed Images/SVM-Datasets/RAW STATIONERY/PENCIL/*.jpg'):
    img = Image.open(filename)
    image_list.append(img)

# append resized images to list
for image in image_list:
    image = image.resize((84,84))
    resized_images.append(image)

# save resized images to new folder
# could also probably use os to create new folder
for (i, new) in enumerate(resized_images):
    new.save('{}{}{}'.format('D:/Datasets/Processed Images/SVM-Datasets/STATIONERY/6_',i+1,'.jpg'))

# %% [markdown]
# # Process Pencil Case Images

# %%
# empty list
image_list = []
resized_images = []

# append image to list
for filename in glob.glob('D:/Datasets/Processed Images/SVM-Datasets/RAW STATIONERY/PENCIL CASE/*.jpg'):
    img = Image.open(filename)
    image_list.append(img)

# append resized images to list
for image in image_list:
    image = image.resize((84,84))
    resized_images.append(image)

# save resized images to new folder
# could also probably use os to create new folder
for (i, new) in enumerate(resized_images):
    new.save('{}{}{}'.format('D:/Datasets/Processed Images/SVM-Datasets/STATIONERY/7_',i+1,'.jpg'))

# %% [markdown]
# # Process Ruler Images

# %%
# empty list
image_list = []
resized_images = []

# append image to list
for filename in glob.glob('D:/Datasets/Processed Images/SVM-Datasets/RAW STATIONERY/RULER/*.jpg'):
    img = Image.open(filename)
    image_list.append(img)

# append resized images to list
for image in image_list:
    image = image.resize((84,84))
    resized_images.append(image)

# save resized images to new folder
# could also probably use os to create new folder
for (i, new) in enumerate(resized_images):
    new.save('{}{}{}'.format('D:/Datasets/Processed Images/SVM-Datasets/STATIONERY/8_',i+1,'.jpg'))

# %% [markdown]
# # Process Scissors Images

# %%
# empty list
image_list = []
resized_images = []

# append image to list
for filename in glob.glob('D:/Datasets/Processed Images/SVM-Datasets/RAW STATIONERY/SCISSOR/*.jpg'):
    img = Image.open(filename)
    image_list.append(img)

# append resized images to list
for image in image_list:
    image = image.resize((84,84))
    resized_images.append(image)

# save resized images to new folder
# could also probably use os to create new folder
for (i, new) in enumerate(resized_images):
    new.save('{}{}{}'.format('D:/Datasets/Processed Images/SVM-Datasets/STATIONERY/9_',i+1,'.jpg'))

# %% [markdown]
# # Process Stappler Images

# %%
# empty list
image_list = []
resized_images = []

# append image to list
for filename in glob.glob('D:/Datasets/Processed Images/SVM-Datasets/RAW STATIONERY/STAPLER/*.jpg'):
    img = Image.open(filename)
    image_list.append(img)

# append resized images to list
for image in image_list:
    image = image.resize((84,84))
    resized_images.append(image)

# save resized images to new folder
# could also probably use os to create new folder
for (i, new) in enumerate(resized_images):
    new.save('{}{}{}'.format('D:/Datasets/Processed Images/SVM-Datasets/STATIONERY/10_',i+1,'.jpg'))

# %% [markdown]
# # Read Images Using OpenCV

# %%
# Import images from training set
train_images = []


for f in glob.iglob("D:/Datasets/Processed Images/SVM-Datasets/STATIONERY/*"):
    image = cv2.imread(f)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    train_images.append(np.asarray(gray))
    
train_images = np.array(train_images)
print(train_images)
# Out:
# [[[153 152 150 ... 151 151 152]
#   [148 148 148 ... 163 163 164]
#   [147 147 148 ... 168 168 169]
#   ...
#   [ 86  81  75 ... 126 126 126]
#   [ 84  78  71 ... 125 125 125]
#   [ 84  78  69 ... 124 124 123]]
#
#  [[155 155 155 ... 194 192 192]
#   [159 159 159 ... 189 188 190]
#   [156 156 156 ... 181 180 181]
#   ...
#   [176 175 167 ... 192 191 190]
#   [172 177 167 ... 193 191 190]
#   [174 185 172 ... 193 192 190]]
#
#  [[213 214 215 ... 102 100  99]
#   [215 216 216 ... 101 100  99]
#   [213 214 215 ... 100  99  99]
#   ...
#   [170 172 172 ... 185 185 185]
#   [175 177 177 ... 187 187 187]
#   [183 184 183 ... 188 188 188]]
#
#  ...
#
#  [[178 174 169 ... 129 144 155]
#   [161 163 166 ... 157 164 165]
#   [173 175 177 ... 166 167 165]
#   ...
#   [172 172 172 ... 137 137 137]
#   [174 173 173 ... 139 139 139]
#   [175 175 174 ... 141 141 141]]
#
#  [[175 176 176 ... 167 166 165]
#   [175 175 175 ... 167 166 166]
#   [174 174 175 ... 167 166 166]
#   ...
# ...

# %%
#printing out its shape
#There are 6000 images with 84*84 pixels
print(train_images.shape)
# Out:
# (6000, 84, 84)

# %% [markdown]
# # Save Image Data To Text File

# %%
np.savetxt("D:/Datasets/Processed Images/SVM-Datasets/stationery_train_data_without_colour.txt", train_images.reshape(6000, 7056))

# %% [markdown]
# # Load Image Data From Text File

# %%
train_folder="D:/Datasets/Processed Images/SVM-Datasets/stationery_train_data_without_colour.txt"
X_train = np.loadtxt(train_folder)

print("Shape of training set: {}".format(X_train.shape))
# Out:
# Shape of training set: (6000, 7056)

# %% [markdown]
# # Find Mean Image

# %%
H = 84
W = 84

# Find the mean image
import matplotlib.pyplot as plt
mean_image = np.mean(X_train, axis = 0)

plt.imshow(np.reshape(mean_image, [H, W]), cmap = plt.get_cmap("gray"))

# %% [markdown]
# # Split Data Before PCA

# %%
path1 = 'D:/Datasets/Processed Images/SVM-Datasets/STATIONERY'
listing = os.listdir(path1)
num_samples=size(listing)
print(num_samples)

target=np.ones((num_samples,),dtype = int)
target[0:600]=0
target[600:1200]=1
target[1200:1800]=2
target[1800:2400]=3
target[2400:3000]=4
target[3000:3600]=5
target[3600:4200]=6
target[4200:4800]=7
target[4800:5400]=8
target[5400:6000]=9

#check the size of target to be 90 before saving it to txt file for future use
print(target.shape)
# Out:
# 6000
# (6000,)

# %% [markdown]
# # Save Target (Label) Into Text File

# %%
np.savetxt("D:/Datasets/Processed Images/SVM-Datasets/stationery_target_without_colour.txt", target)

X_train, X_test, y_train, y_test = train_test_split(X_train, target, random_state=42)

# X is data.
# y is label.
# Random state is 42 to ensure it is constant set to be taken.

# %% [markdown]
# # PCA (Feature Extraction)

# %%
n_components = 30

def image_grid(D,H,W,cols=10,scale=1):
    """ display a grid of images
        H,W: Height and width of the images
        cols: number of columns = number of images in each row
        scale: 1 to fill screen
    """
    n = np.shape(D)[0]
    rows = int(math.ceil((n+0.0)/cols))
    fig = plt.figure(1,figsize=[scale*20.0/H*W,scale*20.0/cols*rows],dpi=300)
    for i in range(n):
        plt.subplot(rows,cols,i+1)
        fig=plt.imshow(np.reshape(D[i,:],[H,W]), cmap = plt.get_cmap("gray"))
        plt.axis('off')

# Extracting the top 50 eigenfaces from the dataset
pca = PCA(n_components=n_components, svd_solver='randomized',
          whiten=True).fit(X_train)

# Showing the eigenfaces
eigenfaces = pca.components_
image_grid(eigenfaces[:,:], H, W)
plt.show()

# PCA the largest eigenbasis has more information (lower noise)
# It is unclear as the image go down

# %%
# Reshape eigenfaces
eigenfaces = eigenfaces.reshape((n_components, H, W))

# Apply PCA to reduce dimension of our image data
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# Plot the graph to find the best number of component
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');
plt.show()

# %% [markdown]
# # Calculate Intra-Class and Inter-Class distance

# %%
# Calculate distances

intra_class_dist = np.sum(np.power((X_train_pca[1,:] - X_test_pca[1,:]),2))
inter_class_dist = np.sum(np.power((X_train_pca[1,:] - X_test_pca[6,:]),2))
print("Intra-class distance: %d" % (intra_class_dist))
print("Inter-class distance: %d" % (inter_class_dist))

# Image of their own is intra class distance
# Image that not belong to them is interclass distance
# The smallest distance means that the image belong to that particular class.

# Intra class smaller the better
# Inter class larger the better
# Out:
# Intra-class distance: 30
# Inter-class distance: 22

# %% [markdown]
# # Feed SVM With Data

# %%
## Train the model with the parameters gamma=0.05 and C=100.

clf = svm.SVC(gamma=0.05, C=100)
clf.fit(X_train_pca,y_train)
# Out:
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.05, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
predictions=clf.predict(X_test_pca)
print(confusion_matrix(y_test, predictions))
# Out:
# [[115  21   4   5   0   1   2  14  10   0]
#  [ 24 113   1   4   1   3   1   5   4   0]
#  [  6   2 139   1   1   0   0   3   3   0]
#  [  9   2   6 108   4   1   2   2   8   5]
#  [  2  13   0   8 101   1   0   1   1  12]
#  [  1   1   0   0   1 139   4   0   1   0]
#  [  0   1   0   0   1   9 131   1   0   1]
#  [ 10   7  12   1   0   1   0 124   4   0]
#  [ 12   7   2   7   3   3   1   2  95   0]
#  [  2   7   0   6  22   0   0   0   2 110]]

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
#print(confusion_matrix(y_test, predictions))
plt.subplots(figsize=(10,10))
cm=confusion_matrix(y_test, predictions)
categories=['Correction Tape','Eraser','File','Glue','Pen','Pencil','Pencil Case','Ruler','Scissors','Stappler']
ax=sns.heatmap(cm,annot=True,cmap='Blues',xticklabels=categories,yticklabels=categories,fmt=".1f")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (10.0, 0.0)

# %%
print(classification_report(y_test, predictions))
#Correction Tape=0
#Eraser=1
#File=2
#Glue=3
#Pen=4
#Pencil=5
#Pencil Case=6
#Ruler=7
#Scissors=8
#Stappler=9
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.65       172
#            1       0.65      0.72      0.68       156
#            2       0.85      0.90      0.87       155
#            3       0.77      0.73      0.75       147
#            4       0.75      0.73      0.74       139
#            5       0.88      0.95      0.91       147
#            6       0.93      0.91      0.92       144
#            7       0.82      0.78      0.80       159
#            8       0.74      0.72      0.73       132
#            9       0.86      0.74      0.79       149
#
#     accuracy                           0.78      1500
#    macro avg       0.79      0.78      0.79      1500
# weighted avg       0.79      0.78      0.78      1500
